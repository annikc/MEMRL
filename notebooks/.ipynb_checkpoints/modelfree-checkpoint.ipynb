# %%
from __future__ import division, print_function
import sys 
sys.path.insert(0,'../rl_network'); import actorcritic as ac;  import stategen as sg
sys.path.insert(0,'../environments/'); import gridworld as eu
import numpy as np
import matplotlib.pyplot as plt
import time
# %matplotlib inline 
fig_savedir = '../data/figures/'
print_freq = 1/10
import importlib

# %%
# environment parameters 
y_height = 8
x_width = 8
walls = False
if not walls:
    y_height = y_height+2
    x_width = x_width+2
rho = 0
maze_type = 'none'
port_shift = 'none'

#make environment
maze = eu.gridworld([y_height, x_width], 
                    rho = rho, 
                    maze_type = maze_type, 
                    port_shift = port_shift, 
                    walls = walls)
#maze.rwd_loc = [(int(y_new/2),int(x_new/2))]
for i in maze.rwd_loc: 
    maze.orig_rwd_loc.append(i)



state_type = 'conv'

if state_type == 'pcs':
    # place cell parameters
    num_pc = 1000
    fwhm = 0.05
    pcs = sg.PlaceCells(num_cells=num_pc, grid=maze, fwhm=fwhm)

    #show environment
    eu.make_env_plots(maze,env=True,pc_map=True,pcs=pcs, save=False)
else: 
    eu.make_env_plots(maze,env=True)

## test out gridworld wrapper. 
env = eu.gymworld(maze)

# %%
if state_type == 'conv':
    num_channels = 3 
    if maze.bound:
        input_dims = (y_height+2,x_width+2,num_channels)
    else: 
        input_dims = (y_height, x_width, num_channels)
    hid_types = ['conv', 'pool', 'linear']
    hid_dims = [(9,9,num_channels), (8,8,num_channels), 500]

elif state_type == 'pcs':
    input_dims = 1000
    hid_types = ['linear']
    hid_dims = [500]
    
action_dims = len(maze.actionlist)
batch_size = 1

NUM_EVENTS = 100
NUM_TRIALS = 5000

# %%
reload(ac)
MF = ac.AC_Net(input_dims, action_dims, batch_size, hid_types, hid_dims)
discount_factor = 0.98

eta = 5e-4 #gradient descent learning rate
opt = ac.optim.Adam(MF.parameters(), lr = eta)

# %%
total_loss = [[],[]]
total_reward = []
val_maps = []

blocktime = time.time()
for trial in range(NUM_TRIALS):
    reward_sum = 0
    if state_type == 'pcs':
        get_pcs = pcs.activity(env.reset())
        state = ac.Variable(ac.torch.FloatTensor(get_pcs))
    elif state_type == 'conv':
        env.reset()
        # because we need to include batch size of 1 
        frame = np.expand_dims(sg.get_frame(maze), axis=0)
        state = ac.Variable(ac.torch.FloatTensor(frame))
        
    MF.reinit_hid()
    for event in range(NUM_EVENTS):
        policy_, value_ = MF(state)
        choice, policy, value = ac.select_action(MF,policy_, value_)
        if event < NUM_EVENTS: 
            next_state, reward, done, info = env.step(choice)

        MF.rewards.append(reward)
        if state_type == 'pcs':
            state = ac.Variable(ac.torch.FloatTensor(pcs.activity(next_state)))       # update state
        elif state_type == 'conv':
            # because we need to include batch size of 1 
            frame = np.expand_dims(sg.get_frame(maze), axis = 0)
            state = ac.Variable(ac.torch.FloatTensor(frame))
        reward_sum += reward

    p_loss, v_loss = ac.finish_trial(MF, discount_factor,opt)
    
    total_loss[0].append(p_loss.data[0])
    total_loss[1].append(v_loss.data[0])
    total_reward.append(reward_sum)
    if state_type == 'pcs':
        value_map = ac.generate_values(maze,MF,pcs=pcs)
    else:
        value_map = ac.generate_values(maze,MF)
    val_maps.append(value_map.copy())
    
    #if trial%10 == 0:
    #    eu.save_value_map(value_map.copy(), maze, trial)
    
    if trial%(print_freq*NUM_TRIALS)==0 or trial == NUM_TRIALS-1: 
        print("[{0}]  Trial {1} total reward = {2} (Avg {3:.3f})".format(time.strftime("%H:%M:%S", time.localtime()), trial, reward_sum, float(reward_sum)/float(NUM_EVENTS)), "Block took {0:.3f}".format(time.time()-blocktime))
        blocktime = time.time()
# Out:
# [16:03:01]  Trial 0 total reward = 0 (Avg 0.000) Block took 0.100
# [16:03:44]  Trial 500 total reward = 7 (Avg 0.070) Block took 42.797
# [16:04:22]  Trial 1000 total reward = 96 (Avg 0.960) Block took 38.344
# [16:05:02]  Trial 1500 total reward = 93 (Avg 0.930) Block took 39.457
# [16:05:41]  Trial 2000 total reward = 90 (Avg 0.900) Block took 39.281
# [16:06:22]  Trial 2500 total reward = 92 (Avg 0.920) Block took 41.099
# [16:07:02]  Trial 3000 total reward = 96 (Avg 0.960) Block took 39.529
# [16:07:48]  Trial 3500 total reward = 89 (Avg 0.890) Block took 46.334
# [16:08:36]  Trial 4000 total reward = 95 (Avg 0.950) Block took 48.297
# [16:09:21]  Trial 4500 total reward = 93 (Avg 0.930) Block took 44.274
# [16:10:07]  Trial 4999 total reward = 96 (Avg 0.960) Block took 46.499

# %%
plt.figure(0)
plt.plot(total_loss[0], label='p')
plt.plot(total_loss[1], label='v')

plt.figure(1)
plt.plot(total_reward, label='r', color='r')

plt.show()
plt.close()

# %%
reload(eu)
eu.print_value_maps(maze,
                    val_maps,
                    maps='all', #list(np.arange(4735, 4999)), 
                    val_range=(0,50),
                    save_dir=fig_savedir,
                    title='Value Map') ### see individual map with kwarg maps=X

# %%
#store_data = {}
store_data[state_type+'relu'] = [total_loss, total_reward, val_maps]

# %%
plt.figure(0)
plt.plot(store_data['convnonrelu'][0][0], label='p_non')
plt.plot(store_data['convrelu'][0][0], label='p_relu')
plt.legend(loc=0)

plt.figure(1)
plt.plot(store_data['convnonrelu'][0][1], label='v_non')
plt.plot(store_data['convrelu'][0][1], label='v_relu')
plt.legend(loc=0)

plt.figure(2)
plt.plot(store_data['convnonrelu'][1], label='r_non')
plt.plot(store_data['convrelu'][1], label='r_relu')
plt.legend(loc=0)

plt.show()
plt.close()
